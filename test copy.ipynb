# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from decpomdp import DecPOMDP
from problem import PROBLEM
import gc 
gc.enable()

# %%
problem_name = "dectiger"
planning_horizon = 2
gametype = "stackelberg"
sota = False
num_iterations = 2

PROBLEM.initialize(DecPOMDP(problem_name,horizon=planning_horizon))
from beliefSpace import BeliefSpace
from pbvi import PBVI

# %%
problem = PROBLEM.get_instance()
print(f"State size = {len(problem.STATES)}")
print(problem.JOINT_ACTIONS)
print(problem.JOINT_OBSERVATIONS)
# Out:
# State size = 2
# [0, 1, 2, 3, 4, 5, 6, 7, 8]
# [0, 1, 2, 3]

# %%
from experiment import Experiment
experiment = Experiment(planning_horizon,num_iterations)
# experiment.run_single_experiment(planning_horizon,gametype="stackelberg",sota=False)

# %%
experiment.run_experiment_decreasing_density(0.2)
# Out:
# 			 Solving cooperative dectiger GAME Horizon 1 WITH SOTA = False
# iteration : 1
# 	belief expansion done with density = 0.2 , resulting belief space size = 2
#
#
# ========== Backup at timestep 0 ==========
# 		belief id : 0 - 1 / 1
#
#
#
# ================================================= END OF cooperative GAME WITH SOTA False ================================================================
#
# 				 alphavectors value at inital belief (V0,V1) : leader =  9.0 , follower = [9. 9.]
#
# ==========================================================================================================================================================================
# iteration : 2
# 	belief expansion done with density = 0.1 , resulting belief space size = 2
#
#
# ========== Backup at timestep 0 ==========
# 		belief id : 0 - 1 / 1
#
#
#
# ================================================= END OF cooperative GAME WITH SOTA False ================================================================
#
# 				 alphavectors value at inital belief (V0,V1) : leader =  9.0 , follower = [9. 9.]
#
# ==========================================================================================================================================================================
# 			 Solving cooperative dectiger GAME Horizon 2 WITH SOTA = False
# iteration : 1
# 	belief expansion done with density = 0.2 , resulting belief space size = 4
#
#
# ========== Backup at timestep 1 ==========
# 		belief id : 0 - 1 / 3
# 		belief id : 1 - 2 / 3
# 		belief id : 2 - 3 / 3
#
# ========== Backup at timestep 0 ==========
# 		belief id : 0 - 1 / 1
#
#
#
# ================================================= END OF cooperative GAME WITH SOTA False ================================================================
#
# 				 alphavectors value at inital belief (V0,V1) : leader =  18.0 , follower = [18. 18.]
#
# ==========================================================================================================================================================================
# iteration : 2
# 	belief expansion done with density = 0.1 , resulting belief space size = 4
#
#
# ========== Backup at timestep 1 ==========
# 		belief id : 0 - 1 / 3
# 		belief id : 1 - 2 / 3
# 		belief id : 2 - 3 / 3
#
# ========== Backup at timestep 0 ==========
# 		belief id : 0 - 1 / 1
#
#
#
# ================================================= END OF cooperative GAME WITH SOTA False ================================================================
#
# 				 alphavectors value at inital belief (V0,V1) : leader =  18.0 , follower = [18. 18.]
#
# ==========================================================================================================================================================================
# 			 Solving cooperative dectiger GAME Horizon 1 WITH SOTA = True
# iteration : 1
# 	belief expansion done with density = 0.2 , resulting belief space size = 2
#
#
# ========== Backup at timestep 0 ==========
# 		belief id : 0 - 1 / 1
#
#
#
# ================================================= END OF cooperative GAME WITH SOTA True ================================================================
#
# 				 alphavectors value at inital belief (V0,V1) : leader =  9.0 , follower = [9. 9.]
#
# ==========================================================================================================================================================================
# iteration : 2
# 	belief expansion done with density = 0.1 , resulting belief space size = 2
#
#
# ========== Backup at timestep 0 ==========
# 		belief id : 0 - 1 / 1
#
#
#
# ================================================= END OF cooperative GAME WITH SOTA True ================================================================
#
# 				 alphavectors value at inital belief (V0,V1) : leader =  9.0 , follower = [9. 9.]
#
# ==========================================================================================================================================================================
# 			 Solving cooperative dectiger GAME Horizon 2 WITH SOTA = True
# iteration : 1
# 	belief expansion done with density = 0.2 , resulting belief space size = 4
#
#
# ========== Backup at timestep 1 ==========
# 		belief id : 0 - 1 / 3
# 		belief id : 1 - 2 / 3
# 		belief id : 2 - 3 / 3
#
# ========== Backup at timestep 0 ==========
# 		belief id : 0 - 1 / 1
#
#
#
# ================================================= END OF cooperative GAME WITH SOTA True ================================================================
#
# 				 alphavectors value at inital belief (V0,V1) : leader =  18.0 , follower = [9. 9.]
#
# ==========================================================================================================================================================================
# iteration : 2
# 	belief expansion done with density = 0.1 , resulting belief space size = 4
#
#
# ========== Backup at timestep 1 ==========
# 		belief id : 0 - 1 / 3
# 		belief id : 1 - 2 / 3
# 		belief id : 2 - 3 / 3
#
# ========== Backup at timestep 0 ==========
# 		belief id : 0 - 1 / 1
#
#
#
# ================================================= END OF cooperative GAME WITH SOTA True ================================================================
#
# 				 alphavectors value at inital belief (V0,V1) : leader =  18.0 , follower = [9. 9.]
#
# ==========================================================================================================================================================================
# 			 Solving zerosum dectiger GAME Horizon 1 WITH SOTA = False
# iteration : 1
# 	belief expansion done with density = 0.2 , resulting belief space size = 2
#
#
# ========== Backup at timestep 0 ==========
# 		belief id : 0 - 1 / 1
#
#
#
# ================================================= END OF zerosum GAME WITH SOTA False ================================================================
#
# 				 alphavectors value at inital belief (V0,V1) : leader =  -75.0 , follower = [65.9375 84.0625]
#
# ==========================================================================================================================================================================
# iteration : 2
# 	belief expansion done with density = 0.1 , resulting belief space size = 2
#
#
# ========== Backup at timestep 0 ==========
# 		belief id : 0 - 1 / 1
#
#
#
# ================================================= END OF zerosum GAME WITH SOTA False ================================================================
#
# 				 alphavectors value at inital belief (V0,V1) : leader =  -75.0 , follower = [65.9375 84.0625]
#
# ==========================================================================================================================================================================
# 			 Solving zerosum dectiger GAME Horizon 2 WITH SOTA = False
# iteration : 1
# 	belief expansion done with density = 0.2 , resulting belief space size = 4
#
#
# ========== Backup at timestep 1 ==========
# 		belief id : 0 - 1 / 3
# 		belief id : 1 - 2 / 3
# 		belief id : 2 - 3 / 3
#
# ========== Backup at timestep 0 ==========
# 		belief id : 0 - 1 / 1
#
#
#
# ================================================= END OF zerosum GAME WITH SOTA False ================================================================
#
# 				 alphavectors value at inital belief (V0,V1) : leader =  -150.0 , follower = [150. 150.]
#
# ==========================================================================================================================================================================
# iteration : 2
# 	belief expansion done with density = 0.1 , resulting belief space size = 4
#
#
# ========== Backup at timestep 1 ==========
# 		belief id : 0 - 1 / 3
# 		belief id : 1 - 2 / 3
# 		belief id : 2 - 3 / 3
#
# ========== Backup at timestep 0 ==========
# 		belief id : 0 - 1 / 1
#
#
#
# ================================================= END OF zerosum GAME WITH SOTA False ================================================================
#
# 				 alphavectors value at inital belief (V0,V1) : leader =  -150.0 , follower = [150. 150.]
#
# ==========================================================================================================================================================================
# 			 Solving zerosum dectiger GAME Horizon 1 WITH SOTA = True
# iteration : 1
# 	belief expansion done with density = 0.2 , resulting belief space size = 2
#
#
# ========== Backup at timestep 0 ==========
# 		belief id : 0 - 1 / 1
#
#
#
# ================================================= END OF zerosum GAME WITH SOTA True ================================================================
#
# 				 alphavectors value at inital belief (V0,V1) : leader =  -75.0 , follower = [84.0625 65.9375]
#
# ==========================================================================================================================================================================
# iteration : 2
# 	belief expansion done with density = 0.1 , resulting belief space size = 2
#
#
# ========== Backup at timestep 0 ==========
# 		belief id : 0 - 1 / 1
#
#
#
# ================================================= END OF zerosum GAME WITH SOTA True ================================================================
#
# 				 alphavectors value at inital belief (V0,V1) : leader =  -75.0 , follower = [84.0625 65.9375]
#
# ==========================================================================================================================================================================
# 			 Solving zerosum dectiger GAME Horizon 2 WITH SOTA = True
# iteration : 1
# 	belief expansion done with density = 0.2 , resulting belief space size = 4
#
#
# ========== Backup at timestep 1 ==========
# 		belief id : 0 - 1 / 3
# 		belief id : 1 - 2 / 3
# 		belief id : 2 - 3 / 3
#
# ========== Backup at timestep 0 ==========
# 		belief id : 0 - 1 / 1
#
#
#
# ================================================= END OF zerosum GAME WITH SOTA True ================================================================
#
# 				 alphavectors value at inital belief (V0,V1) : leader =  -150.0 , follower = [84.0625 65.9375]
#
# ==========================================================================================================================================================================
# iteration : 2
# 	belief expansion done with density = 0.1 , resulting belief space size = 4
#
#
# ========== Backup at timestep 1 ==========
# 		belief id : 0 - 1 / 3
# 		belief id : 1 - 2 / 3
# 		belief id : 2 - 3 / 3
#
# ========== Backup at timestep 0 ==========
# 		belief id : 0 - 1 / 1
#
#
#
# ================================================= END OF zerosum GAME WITH SOTA True ================================================================
#
# 				 alphavectors value at inital belief (V0,V1) : leader =  -150.0 , follower = [84.0625 65.9375]
#
# ==========================================================================================================================================================================
# 			 Solving stackelberg dectiger GAME Horizon 1 WITH SOTA = False
# iteration : 1
# 	belief expansion done with density = 0.2 , resulting belief space size = 2
#
#
# ========== Backup at timestep 0 ==========
# 		belief id : 0 - 1 / 1
#
#
#
# ================================================= END OF stackelberg GAME WITH SOTA False ================================================================
#
# 				 alphavectors value at inital belief (V0,V1) : leader =  3.5 , follower = [-20.  -7.]
#
# ==========================================================================================================================================================================
# iteration : 2
# 	belief expansion done with density = 0.1 , resulting belief space size = 2
#
#
# ========== Backup at timestep 0 ==========
# 		belief id : 0 - 1 / 1
#
#
#
# ================================================= END OF stackelberg GAME WITH SOTA False ================================================================
#
# 				 alphavectors value at inital belief (V0,V1) : leader =  3.5 , follower = [-20.  -7.]
#
# ==========================================================================================================================================================================
# 			 Solving stackelberg dectiger GAME Horizon 2 WITH SOTA = False
# iteration : 1
# 	belief expansion done with density = 0.2 , resulting belief space size = 4
#
#
# ========== Backup at timestep 1 ==========
# 		belief id : 0 - 1 / 3
# 		belief id : 1 - 2 / 3
# 		belief id : 2 - 3 / 3
#
# ========== Backup at timestep 0 ==========
# 		belief id : 0 - 1 / 1
#
#
#
# ================================================= END OF stackelberg GAME WITH SOTA False ================================================================
#
# 				 alphavectors value at inital belief (V0,V1) : leader =  10.486484375 , follower = [-16.67921875 -14.        ]
#
# ==========================================================================================================================================================================
# iteration : 2
# 	belief expansion done with density = 0.1 , resulting belief space size = 4
#
#
# ========== Backup at timestep 1 ==========
# 		belief id : 0 - 1 / 3
# 		belief id : 1 - 2 / 3
# 		belief id : 2 - 3 / 3
#
# ========== Backup at timestep 0 ==========
# 		belief id : 0 - 1 / 1
#
#
#
# ================================================= END OF stackelberg GAME WITH SOTA False ================================================================
#
# 				 alphavectors value at inital belief (V0,V1) : leader =  10.486484375 , follower = [-16.67921875 -14.        ]
#
# ==========================================================================================================================================================================
# 			 Solving stackelberg dectiger GAME Horizon 1 WITH SOTA = True
# iteration : 1
# 	belief expansion done with density = 0.2 , resulting belief space size = 2
#
#
# ========== Backup at timestep 0 ==========
# 		belief id : 0 - 1 / 1
#
#
#
# ================================================= END OF stackelberg GAME WITH SOTA True ================================================================
#
# 				 alphavectors value at inital belief (V0,V1) : leader =  3.5 , follower = [-20.  -7.]
#
# ==========================================================================================================================================================================
# iteration : 2
# 	belief expansion done with density = 0.1 , resulting belief space size = 2
#
#
# ========== Backup at timestep 0 ==========
# 		belief id : 0 - 1 / 1
#
#
#
# ================================================= END OF stackelberg GAME WITH SOTA True ================================================================
#
# 				 alphavectors value at inital belief (V0,V1) : leader =  3.5 , follower = [-20.  -7.]
#
# ==========================================================================================================================================================================
# 			 Solving stackelberg dectiger GAME Horizon 2 WITH SOTA = True
# iteration : 1
# 	belief expansion done with density = 0.2 , resulting belief space size = 4
#
#
# ========== Backup at timestep 1 ==========
# 		belief id : 0 - 1 / 3
# 		belief id : 1 - 2 / 3
# 		belief id : 2 - 3 / 3
#
# ========== Backup at timestep 0 ==========
# 		belief id : 0 - 1 / 1
#
#
#
# ================================================= END OF stackelberg GAME WITH SOTA True ================================================================
#
# 				 alphavectors value at inital belief (V0,V1) : leader =  10.486484375 , follower = [-20.  -7.]
#
# ==========================================================================================================================================================================
# iteration : 2
# 	belief expansion done with density = 0.1 , resulting belief space size = 4
#
#
# ========== Backup at timestep 1 ==========
# 		belief id : 0 - 1 / 3
# 		belief id : 1 - 2 / 3
# 		belief id : 2 - 3 / 3
#
# ========== Backup at timestep 0 ==========
# 		belief id : 0 - 1 / 1
#
#
#
# ================================================= END OF stackelberg GAME WITH SOTA True ================================================================
#
# 				 alphavectors value at inital belief (V0,V1) : leader =  10.486484375 , follower = [-20.  -7.]
#
# ==========================================================================================================================================================================
# Constructing Stackelberg Comparison matrix..
# timestep = 1
# 	belief = 0,	value :: {0: {0: -1.0, 1: 4.5}, 1: {0: -10.0, 1: -3.5}}
# 	belief = 1,	value :: {0: {0: 8.728187919463089, 1: -3.0201342281879193}, 1: {0: 12.607382550335572, 1: -0.785234899328859}}
# 	belief = 2,	value :: {0: {0: -1.3684983221476512, 1: -97.52537751677853}, 1: {0: -1.304320469798658, 1: -41.155830536912745}}
# timestep = 0
# 	belief = 0,	value :: {0: {0: 5.020324559563759, 1: 6.25}, 1: {0: -3.470513317953019, 1: -10.25}}
# timestep = 1
# 	belief = 0,	value :: {0: {0: -1.0, 1: 4.5}, 1: {0: -10.0, 1: -3.5}}
# 	belief = 1,	value :: {0: {0: 8.728187919463089, 1: -3.0201342281879193}, 1: {0: 12.607382550335572, 1: -0.785234899328859}}
# 	belief = 2,	value :: {0: {0: -1.3684983221476512, 1: -97.52537751677853}, 1: {0: -1.304320469798658, 1: -41.155830536912745}}
# timestep = 0
# 	belief = 0,	value :: {0: {0: 5.020324559563759, 1: 6.25}, 1: {0: -3.470513317953019, 1: -10.25}}
# Done.. in 0.0014531612396240234 seconds... exporting to csv..
#        gametype              SOTA  horizon  iterations      time  \
# 0   cooperative       Stackelberg        1           1  0.026433
# 1   cooperative       Stackelberg        1           2  0.020715
# 2   cooperative       Stackelberg        2           1  0.063162
# 3   cooperative       Stackelberg        2           2  0.063739
# 4   cooperative  State of the Art        1           1  0.000156
# 5   cooperative  State of the Art        1           2  0.000125
# 6   cooperative  State of the Art        2           1  0.001821
# 7   cooperative  State of the Art        2           2  0.002256
# 8       zerosum       Stackelberg        1           1  0.018927
# 9       zerosum       Stackelberg        1           2  0.018897
# 10      zerosum       Stackelberg        2           1  0.076751
# 11      zerosum       Stackelberg        2           2  0.073777
# 12      zerosum  State of the Art        1           1  0.020548
# 13      zerosum  State of the Art        1           2  0.019057
# 14      zerosum  State of the Art        2           1  0.076837
# 15      zerosum  State of the Art        2           2  0.079992
# 16  stackelberg       Stackelberg        1           1  0.015876
# 17  stackelberg       Stackelberg        1           2  0.024846
# 18  stackelberg       Stackelberg        2           1  0.080940
# 19  stackelberg       Stackelberg        2           2  0.146092
# 20  stackelberg  State of the Art        1           1  0.015202
# 21  stackelberg  State of the Art        1           2  0.015236
# 22  stackelberg  State of the Art        2           1  0.071711
# 23  stackelberg  State of the Art        2           2  0.061830
#
#     number_of_beliefs  leader values               follower values  density
# 0                   2       9.000000                    [9.0, 9.0]      0.2
# 1                   2       9.000000                    [9.0, 9.0]      0.1
# 2                   4      18.000000                  [18.0, 18.0]      0.2
# 3                   4      18.000000                  [18.0, 18.0]      0.1
# 4                   2       9.000000                    [9.0, 9.0]      0.2
# 5                   2       9.000000                    [9.0, 9.0]      0.1
# 6                   4      18.000000                    [9.0, 9.0]      0.2
# 7                   4      18.000000                    [9.0, 9.0]      0.1
# 8                   2     -75.000000  [65.9375, 84.06249999999999]      0.2
# 9                   2     -75.000000  [65.9375, 84.06249999999999]      0.1
# 10                  4    -150.000000                [150.0, 150.0]      0.2
# 11                  4    -150.000000                [150.0, 150.0]      0.1
# 12                  2     -75.000000  [84.06249999999999, 65.9375]      0.2
# 13                  2     -75.000000  [84.06249999999999, 65.9375]      0.1
# 14                  4    -150.000000  [84.06249999999999, 65.9375]      0.2
# 15                  4    -150.000000  [84.06249999999999, 65.9375]      0.1
# 16                  2       3.500000                 [-20.0, -7.0]      0.2
# 17                  2       3.500000                 [-20.0, -7.0]      0.1
# 18                  4      10.486484         [-16.67921875, -14.0]      0.2
# 19                  4      10.486484         [-16.67921875, -14.0]      0.1
# 20                  2       3.500000                 [-20.0, -7.0]      0.2
# 21                  2       3.500000                 [-20.0, -7.0]      0.1
# 22                  4      10.486484                 [-20.0, -7.0]      0.2
# 23                  4      10.486484                 [-20.0, -7.0]      0.1

# %%
experiment.construct_stackelberg_comparison_matrix()
experiment.comparison_matrix
# Out:
# Constructing Stackelberg Comparison matrix..
# timestep = 1
# 	belief = 0,	value :: {0: {0: -1.0, 1: 4.5}, 1: {0: -10.0, 1: -3.5}}
# 	belief = 1,	value :: {0: {0: 8.728187919463089, 1: -3.0201342281879193}, 1: {0: 12.607382550335572, 1: -0.785234899328859}}
# 	belief = 2,	value :: {0: {0: -1.3684983221476512, 1: -97.52537751677853}, 1: {0: -1.304320469798658, 1: -41.155830536912745}}
# timestep = 0
# 	belief = 0,	value :: {0: {0: 5.020324559563759, 1: 6.25}, 1: {0: -3.470513317953019, 1: -10.25}}
# timestep = 1
# 	belief = 0,	value :: {0: {0: -1.0, 1: 4.5}, 1: {0: -10.0, 1: -3.5}}
# 	belief = 1,	value :: {0: {0: 8.728187919463089, 1: -3.0201342281879193}, 1: {0: 12.607382550335572, 1: -0.785234899328859}}
# 	belief = 2,	value :: {0: {0: -1.3684983221476512, 1: -97.52537751677853}, 1: {0: -1.304320469798658, 1: -41.155830536912745}}
# timestep = 0
# 	belief = 0,	value :: {0: {0: 5.020324559563759, 1: 6.25}, 1: {0: -3.470513317953019, 1: -10.25}}
# Done.. in 0.0017211437225341797 seconds... exporting to csv..
#                                            Strong Leader Policy  \
# Strong Follower Policy            (10.486484375, -15.339609375)
# Blind Follower Policy   [5.63516227978188, -6.8602566589765095]
#
#                                              Weak Leader Policy
# Strong Follower Policy  [5.63516227978188, -6.8602566589765095]
# Blind Follower Policy                     (10.486484375, -13.5)

# %%
tables = experiment.generate_summary_table()
tables["zerosum"]
# Out:
#             State of the Art                        Stackelberg               \
#                         time leader value iteration        time leader value
# dectiger(1)         0.020548        -75.0         2    0.018927        -75.0
# dectiger(2)         0.076837       -150.0         2    0.076751       -150.0
#
#
#             iteration
# dectiger(1)         2
# dectiger(2)         2

# %%
experiment.generate_comparison_tables()
# Out:
#                               cooperative                           \
#             State of the Art Leader Value Stackelberg Leader Value
# dectiger(1)                           9.0                      9.0
# dectiger(2)                          18.0                     18.0
#
#                                   zerosum                           \
#             State of the Art Leader Value Stackelberg Leader Value
# dectiger(1)                         -75.0                    -75.0
# dectiger(2)                        -150.0                   -150.0
#
#                               general-sum
#             State of the Art Leader Value Stackelberg Leader Value
# dectiger(1)                      3.500000                 3.500000
# dectiger(2)                     10.486484                10.486484

# %%
experiment.plots()

# %%
experiment.horizon_value_plot()
